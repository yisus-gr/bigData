# %%
import pandas as pd

# %%
df = pd.read_csv('viajes_surfistas.csv')
df
# Out:
#                            homename  homecontinent               homecountry  \
# 0            Canadian in La La Land  North America  United States of America
# 1            Canadian in La La Land  North America  United States of America
# 2            Canadian in La La Land  North America  United States of America
# 3            Canadian in La La Land  North America  United States of America
# 4            Canadian in La La Land  North America  United States of America
# ...                             ...            ...                       ...
# 9506  Bridgetown, Western Australia      Australia                 Australia
# 9507                  Lille, France         Europe                    France
# 9508                             MX  South America                    Mexico
# 9509        Kuta - Bali - Indonesia           Asia                 Indonesia
# 9510        Kuta - Bali - Indonesia           Asia                 Indonesia
#
# ...

# %%
df["paisOrigen"] = df["homecountry"].apply(
    lambda x: x if x == "United States of America" or x == "Japan" or x == "Australia" or x == "Spain" else "Otros")
df
# Out:
#                            homename  homecontinent               homecountry  \
# 0            Canadian in La La Land  North America  United States of America
# 1            Canadian in La La Land  North America  United States of America
# 2            Canadian in La La Land  North America  United States of America
# 3            Canadian in La La Land  North America  United States of America
# 4            Canadian in La La Land  North America  United States of America
# ...                             ...            ...                       ...
# 9506  Bridgetown, Western Australia      Australia                 Australia
# 9507                  Lille, France         Europe                    France
# 9508                             MX  South America                    Mexico
# 9509        Kuta - Bali - Indonesia           Asia                 Indonesia
# 9510        Kuta - Bali - Indonesia           Asia                 Indonesia
#
# ...

# %%
paises = df.groupby('paisOrigen').count()
paises
# Out:
#                           homename  homecontinent  homecountry  homelat  \
# paisOrigen
# Australia                      809            809          809      809
# Japan                          893            893          893      893
# Otros                         4231           4231         4231     4231
# Spain                          752            752          752      752
# United States of America      2826           2826         2826     2826
#
#                           homelon  travelcontinent  travelcountry  travellat  \
# paisOrigen
# Australia                     809              809            809        809
# Japan                         893              893            893        893
# Otros                        4231             4231           4231       4231
# Spain                         752              752            752        752
# United States of America     2826             2826           2826       2826
#
#                           travellon
# ...

# %%
paises = paises.sort_values(by='homecountry') #ordenamos los paises por cantidad de participantes
paises
# Out:
#                           homename  homecontinent  homecountry  homelat  \
# paisOrigen
# Spain                          752            752          752      752
# Australia                      809            809          809      809
# Japan                          893            893          893      893
# United States of America      2826           2826         2826     2826
# Otros                         4231           4231         4231     4231
#
#                           homelon  travelcontinent  travelcountry  travellat  \
# paisOrigen
# Spain                         752              752            752        752
# Australia                     809              809            809        809
# Japan                         893              893            893        893
# United States of America     2826             2826           2826       2826
# Otros                        4231             4231           4231       4231
#
#                           travellon
# ...

# %%
paises.plot.pie(y="homename", startangle=90, autopct='%1.1f%%', )
# Out:
# <Axes: ylabel='homename'>
